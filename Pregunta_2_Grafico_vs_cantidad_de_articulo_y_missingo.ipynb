# %% [markdown]
# Autor: Jesus Alvarado-Huayhuaz
#
# inefable12@gmail.com

# %% [markdown]
# # Requerimientos

# %% [markdown]
# ## PyScopus

# %%
# !pip install pyscopus==1.0.3a2
# Out:
# Requirement already satisfied: pyscopus==1.0.3a2 in /usr/local/lib/python3.10/dist-packages (1.0.3a2)

# %% [markdown]
# Librerías

# %%
from pyscopus import Scopus
import numpy
import pandas
import requests

# %% [markdown]
# ### Enlace del Colab con Scopus (API KEY)
#
# *   El usuario debe disponer de una clave **personal**
# *   Más información en https://dev.elsevier.com/

# %%
key = "249b81ceece6cd8662b8968b0bac229c"
scopus = Scopus(key)

# %% [markdown]
# ## Búsqueda:
#
# Ejemplo:
#
# TITLE-ABS-KEY((("oxytocin") AND ("cheminformatics") AND ("docking")) OR ("oxytocin" AND "dog" AND "docking")  OR ("oxytocin" AND "virtual" AND "simulations"))

# %%
s = input("( TITLE-ABS-KEY ( coccidia ) AND TITLE-ABS-KEY ( peru ) AND TITLE-ABS-KEY ( faeces ) )")
search_df = scopus.search(s, count=200,view='STANDARD')
# Out:
# ( TITLE-ABS-KEY ( coccidia ) AND TITLE-ABS-KEY ( peru ) AND TITLE-ABS-KEY ( faeces ) )( TITLE-ABS-KEY ( coccidia ) AND TITLE-ABS-KEY ( peru ) AND TITLE-ABS-KEY ( faeces ) )

# %%
from IPython.display import display
display(search_df)
# Out:
#       scopus_id                                              title  \
# 0   85013360351  Intestinal coccidiosis in children admitted to...
# 1   84931447839  New records of parasites in free-ranging Andea...
# 2   84896739816  Genetic characterization of human-pathogenic C...
# 3   57849155418  New species of eimeria and isospora (Protozoa:...
# 4   33747831831  A new Eimeria (Apicomplexa: Eimeriidae), posse...
# 5    0034323660  Description of Eimeria motelo sp. n. (Apicompl...
# 6    0033502711  Cyclospora cayetanensis: Diagnosis and situati...
# 7    0032471411                            Cyclospora cayetanensis
# 8    0029384711  A survey for selected viral, chlamydial, and p...
# 9    0028677311  Intestinal co-infection by Cyclospora sp. and ...
# 10   0027253862  Cyclospora Species – A New Protozoan Pathogen ...
# 11   0027393442  Clinical Characteristics of Seven Cases of Dia...
# 12   0015012014  Eimeria macusaniensis n. sp. (Protozoa: Eimeri...
#
#                                      publication_name      issn  isbn  \
# 0   Revista Peruana de Medicina Experimental y Sal...  17264634  None
# 1                                               Ursus  15376176  None
# 2                   Infection, Genetics and Evolution  15671348  None
# 3                                            Parasite  1252607X  None
# 4                  Memorias do Instituto Oswaldo Cruz  00740276  None
# 5                  Memorias do Instituto Oswaldo Cruz  00740276  None
# 6                           Archives of Public Health  07787367  None
# 7                            Advances in Parasitology  0065308X  None
# 8                        Journal of wildlife diseases  00903558  None
# 9                                            Parasite  1252607X  None
# 10                    New England Journal of Medicine  00284793  None
# 11                       Clinical Infectious Diseases  10584838  None
# 12                        The Journal of Protozoology  00223921  None
#
#        eissn volume page_range  cover_date  \
# 0   17264642     33    739-744  2016-10-01
# 1       None     26      21-27  2015-05-01
# 2   15677257     22    229-234  2014-03-01
# 3       None     15    531-538  2008-01-01
# 4   16788060    101    555-558  2006-01-01
# 5       None     95    829-832  2000-01-01
# 6       None     57    301-310  1999-12-01
# 7       None     40    399-418  1998-01-01
# 8       None     31    523-528  1995-01-01
# 9   17761042      1    387-390  1994-01-01
# 10  15334406    328  1308-1312  1993-05-06
# 11  15376591     16    136-138  1993-01-01
# 12  15507408     18    162-163  1971-01-01
#
#                                    doi  citation_count  \
# 0        10.17843/rpmesp.2016.334.2560               7
# 1           10.2192/URSUS-D-14-00034.1              14
# 2         10.1016/j.meegid.2013.07.015              39
# 3          10.1051/parasite/2008154531              11
# 4      10.1590/S0074-02762006000500013               9
# 5      10.1590/S0074-02762000000600013              13
# 6                                 None               1
# 7        10.1016/S0065-308X(08)60128-1              72
# 8           10.7589/0090-3558-31.4.523              42
# 9          10.1051/parasite/1994014387              15
# 10         10.1056/NEJM199305063281804             384
# 11            10.1093/clinids/16.1.136              69
# 12  10.1111/j.1550-7408.1971.tb03299.x              34
#
#                                           affiliation aggregation_type  \
# 0   [{'name': 'Hospital Regional Lambayeque', 'cit...          Journal
# 1   [{'name': 'Asociación para la Investigación y ...          Journal
# 2   [{'name': 'Food and Drug Administration', 'cit...          Journal
# 3   [{'name': 'Instituto Evandro Chagas', 'city': ...          Journal
# 4   [{'name': 'Veterinární Univerzita Brno', 'city...          Journal
# 5   [{'name': 'Veterinární Univerzita Brno', 'city...          Journal
# 6   [{'name': 'Scientific Institute of Public Heal...          Journal
# 7   [{'name': 'The University of Arizona', 'city':...      Book Series
# 8   [{'name': 'California National Primate Researc...          Journal
# 9   [{'name': 'Fondazione IRCCS Policlinico San Ma...          Journal
# 10  [{'name': 'The University of Arizona', 'city':...          Journal
# 11  [{'name': 'Northwestern Memorial Hospital', 'c...          Journal
# 12  [{'name': 'Universidad Nacional Mayor de San M...          Journal
#
#    subtype_description authors  \
# 0              Article      []
# 1              Article      []
# 2              Article      []
# 3              Article      []
# 4              Article      []
# 5              Article      []
# 6              Article      []
# 7              Article      []
# 8              Article      []
# 9              Article      []
# 10             Article      []
# 11             Article      []
# 12             Article      []
#
#                                             full_text
# 0                                                None
# 1                                                None
# 2   https://api.elsevier.com/content/article/eid/1...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7   https://api.elsevier.com/content/article/eid/1...
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None

# %% [markdown]
# ## Artículos, conference papers, books, etc

# %%
search_df.subtype_description.unique()
# Out:
# array(['Article'], dtype=object)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Contar las ocurrencias de cada tipo de publicación y ordenar los datos por el índice
subtype_description = search_df['subtype_description'].value_counts()

# Crear el gráfico de barras con coloración por tipo de publicación
ax = sns.barplot(x=subtype_description.index, y=subtype_description.values, palette='viridis')

# Agregar etiquetas y título
plt.ylabel('Cantidad')
plt.title('Tipo de publicación')

# Formatear el eje y con un decimal
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%.0f'))

# Mostrar el gráfico
plt.show()
# Out:
# <ipython-input-18-c525a455e4cc>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=subtype_description.index, y=subtype_description.values, palette='viridis')

# %%
import pandas as pd

# Dividir la columna "cover_date" y crear la columna "year"
search_df['year'] = search_df['cover_date'].apply(lambda x: x.split('-')[0])

# %%
search_df.head(3)
# Out:
#      scopus_id                                              title  \
# 0  85013360351  Intestinal coccidiosis in children admitted to...
# 1  84931447839  New records of parasites in free-ranging Andea...
# 2  84896739816  Genetic characterization of human-pathogenic C...
#
#                                     publication_name      issn  isbn  \
# 0  Revista Peruana de Medicina Experimental y Sal...  17264634  None
# 1                                              Ursus  15376176  None
# 2                  Infection, Genetics and Evolution  15671348  None
#
#       eissn volume page_range  cover_date                            doi  \
# 0  17264642     33    739-744  2016-10-01  10.17843/rpmesp.2016.334.2560
# 1      None     26      21-27  2015-05-01     10.2192/URSUS-D-14-00034.1
# 2  15677257     22    229-234  2014-03-01   10.1016/j.meegid.2013.07.015
#
#    citation_count                                        affiliation  \
# 0               7  [{'name': 'Hospital Regional Lambayeque', 'cit...
# 1              14  [{'name': 'Asociación para la Investigación y ...
# 2              39  [{'name': 'Food and Drug Administration', 'cit...
#
#   aggregation_type subtype_description authors  \
# 0          Journal             Article      []
# 1          Journal             Article      []
# 2          Journal             Article      []
#
#                                            full_text  year
# 0                                               None  2016
# 1                                               None  2015
# 2  https://api.elsevier.com/content/article/eid/1...  2014

# %% [markdown]
# ## Frecuencia de publicaciones por año

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Contar las ocurrencias de cada año y ordenar los datos por el índice
year_counts = search_df['year'].value_counts().sort_index()

# Crear el gráfico de barras con coloración por año
ax = sns.barplot(x=year_counts.index, y=year_counts.values, palette='viridis')

# Agregar etiquetas y título
plt.xlabel('Año')
plt.ylabel('Número de publicaciones')
plt.title('Publicaciones por año')
plt.xticks(rotation=45)

# Establecer los valores del eje y
ax.set_yticks([1, 2, 3, 4])

# Mostrar el gráfico
plt.show()
# Out:
# <ipython-input-21-ea52143cf8a9>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=year_counts.index, y=year_counts.values, palette='viridis')

# %%
search_df.citation_count.unique()
# Out:
# array([  7,  14,  39,  11,   9,  13,   1,  72,  42,  15, 384,  69,  34])

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Crear un DataFrame de ejemplo
df = pd.DataFrame(search_df) #.sort_index(ascending=False)

# Crear el gráfico de dispersión con coloración por recurrencia
sns.scatterplot(data=df, x='publication_name', y='year', hue='citation_count', palette='viridis')

# Agregar etiquetas y título
plt.xlabel('Revistas')
plt.ylabel('Año')
plt.title('Revistas y año de publicación')
plt.xticks(rotation=90)

# Cambiar el título de la leyenda
plt.legend(title='Citaciones')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Análisis descriptivo

# %%
print("Cantidad de Filas y columnas:", search_df.shape)
# Out:
# Cantidad de Filas y columnas: (13, 17)

# %%
print('Nombre columnas:',search_df.columns)
# Out:
# Nombre columnas: Index(['scopus_id', 'title', 'publication_name', 'issn', 'isbn', 'eissn',
#        'volume', 'page_range', 'cover_date', 'doi', 'citation_count',
#        'affiliation', 'aggregation_type', 'subtype_description', 'authors',
#        'full_text', 'year'],
#       dtype='object')

# %%
search_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   scopus_id            13 non-null     object
#  1   title                13 non-null     object
#  2   publication_name     13 non-null     object
#  3   issn                 13 non-null     object
#  4   isbn                 0 non-null      object
#  5   eissn                7 non-null      object
#  6   volume               13 non-null     object
#  7   page_range           13 non-null     object
#  8   cover_date           13 non-null     object
#  9   doi                  12 non-null     object
#  10  citation_count       13 non-null     int64
#  11  affiliation          13 non-null     object
#  12  aggregation_type     13 non-null     object
#  13  subtype_description  13 non-null     object
#  14  authors              13 non-null     object
#  15  full_text            2 non-null      object
#  16  year                 13 non-null     object
# dtypes: int64(1), object(16)
# memory usage: 1.9+ KB

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Crear un DataFrame de ejemplo
df = pd.DataFrame(search_df)

# Crear el gráfico de barras
plt.bar(df['publication_name'], df['citation_count'])

# Agregar etiquetas y título
plt.xlabel('publication_name')
plt.ylabel('citation_count')
plt.title('citation_count por publication_name')
plt.xticks(rotation=90)

# Mostrar el gráfico
plt.show()

# %%
# !wget https://raw.githubusercontent.com/yviguria/Parcial-1-entregables/main/busqueda_scopus.csv
# Out:
# --2024-09-09 09:29:56--  https://raw.githubusercontent.com/yviguria/Parcial-1-entregables/main/busqueda_scopus.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27195 (27K) [text/plain]
# Saving to: ‘busqueda_scopus.csv’
#
# busqueda_scopus.csv 100%[===================>]  26.56K  --.-KB/s    in 0.003s
#
# 2024-09-09 09:29:56 (8.41 MB/s) - ‘busqueda_scopus.csv’ saved [27195/27195]

# %%
import pandas as pd
collisions = pd.read_csv("https://raw.githubusercontent.com/yviguria/Parcial-1-entregables/main/busqueda_scopus.csv")

# %%
import missingno as msn
msn.matrix(df)
get_ipython().run_line_magic('matplotlib', 'inline')

# Ajustar el tamaño de la muestra
sample_size = min(250, len(collisions))
msn.matrix(collisions.sample(sample_size))
# Out:
# <Axes: >
